# %% [markdown]
# ```
# # what is Pandas
# **bold text**
#
# *   pandas is a fast , powerfoull , flexble and easy to use open source data analysis and munipulation tool, build on the top of the python programming langauge
#
# #pandas Series
# * A Pandas series is link a column in a table . it is a 1-D array holdinag data of any type
# ```

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# series from list

# %%
#string
country = ['India','Pakistan','Bangladesh','Srilanka','Afghanistan']
# number =['1','2','3','4','5']
pd.Series(country)
# Out:
# 0          India
# 1       Pakistan
# 2     Bangladesh
# 3       Srilanka
# 4    Afghanistan
# dtype: object

# %%
#integers
runs = [13,24,67,23,23]
pd.Series(runs)
# Out:
# 0    13
# 1    24
# 2    67
# 3    23
# 4    23
# dtype: int64

# %%
#custom indes
marks =[65,45,23,23]
subject = ['maths','nepali','english','science']
pd.Series(marks,index=subject)
# Out:
# maths      65
# nepali     45
# english    23
# science    23
# dtype: int64

# %%
#stting a name
pd.Series(marks,index=subject,name='prabin marks')
# Out:
# maths      65
# nepali     45
# english    23
# science    23
# Name: prabin marks, dtype: int64

# %% [markdown]
# series form dict

# %%
marks ={
    'maths':65,
    'nepali':45,
    'english':23,
    'science':23
    }

marks_series=pd.Series(marks)
marks_series
# Out:
# maths      65
# nepali     45
# english    23
# science    23
# dtype: int64

# %% [markdown]
# size
# (how many items)

# %%
marks_series.size
# Out:
# 4

# %% [markdown]
# dtype ( what kind of data you have )

# %%
marks_series.dtype
# Out:
# dtype('int64')

# %% [markdown]
# name

# %%
marks_series.name

# %% [markdown]
# is_unique

# %%
marks_series.is_unique
# Out:
# False

# %% [markdown]
# index

# %%
marks_series.index#[0]
# Out:
# 'maths'

# %% [markdown]
# values

# %%
marks_series.values
# Out:
# array([65, 45, 23, 23])

# %% [markdown]
# series using read_csv

# %%
subs = pd.read_csv('subs.csv')
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
bollywood = pd.read_csv('bollywood.csv')
bollywood
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %% [markdown]
# convert to the series

# %%
if bollywood.shape[1] == 1:
    df = bollywood.iloc[:, 0]  # Convert single-column DataFrame to Series

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-b05c31376ced> in <cell line: 4>()
#       2     df = bollywood.iloc[:, 0]  # Convert single-column DataFrame to Series
#       3
# ----> 4 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# series methods

# %%
# head  (first 5)
bollywood.head()
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     Vicky Kaushal
# 1                         Battalion 609       Vicky Ahuja
# 2  The Accidental Prime Minister (film)       Anupam Kher
# 3                       Why Cheat India     Emraan Hashmi
# 4                       Evening Shadows  Mona Ambegaonkar

# %%
# taill (last 5)
bollywood.tail()
# Out:
#                        movie              lead
# 1495  Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496     Aankhen (2002 film)  Amitabh Bachchan
# 1497         Saathiya (film)      Vivek Oberoi
# 1498          Company (film)        Ajay Devgn
# 1499    Awara Paagal Deewana      Akshay Kumar

# %% [markdown]
# sample (random on row fatch)

# %%
bollywood.sample(4) # what ever number you give fetch the row
# Out:
#              movie               lead
# 647  Wake Up India       Elisha Kriis
# 529  Finding Fanny   Deepika Padukone
# 985     Bhoothnath   Amitabh Bachchan
# 813      Damadamm!  Himesh Reshammiya

# %% [markdown]
# value counts -> frequency

# %%
bollywood.value_counts()
# Out:
# movie                     lead
# Andaaz                    Akshay Kumar        2
# Tanu Weds Manu: Returns   Kangana Ranaut      2
# Gabbar Is Back            Akshay Kumar        2
# 1920 (film)               Rajniesh Duggall    1
# Newton (film)             Rajkummar Rao       1
#                                              ..
# Ghayal: Once Again        Sunny Deol          1
# Ghanchakkar (film)        Vidya Balan         1
# Ghajini (2008 film)       Aamir Khan          1
# Genius (2018 Hindi film)  Utkarsh Sharma      1
# Zor Lagaa Ke...Haiya!     Meghan Jadhav       1
# Name: count, Length: 1497, dtype: int64

# %%
# prompt: i wnat to count the  lead actor how many  time play

import pandas as pd

# Assuming your Bollywood data is in a DataFrame called 'bollywood'
# and the column containing the lead actor is named 'Lead Actor'

lead_actor_counts = bollywood['lead'].value_counts()

print(lead_actor_counts)
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %% [markdown]
# Movie count

# %%
movie_count = bollywood['movie'].value_counts()
movie_count
# Out:
# movie
# Tanu Weds Manu: Returns        2
# Gabbar Is Back                 2
# Andaaz                         2
# Uri: The Surgical Strike       1
# Jannat (film)                  1
#                               ..
# Hawaa Hawaai                   1
# Children of War (2014 film)    1
# The Xposé                      1
# Mastram                        1
# Awara Paagal Deewana           1
# Name: count, Length: 1497, dtype: int64

# %% [markdown]
# Short valu

# %%
vk = pd.read_csv('kohli_ipl.csv')
vk
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %% [markdown]
# short valu base on the runs

# %%
runshort = vk['runs'].sort_values(ascending=False).head(10)
runshort
# Out:
# 127    113
# 125    109
# 122    108
# 163    100
# 119    100
# 81      99
# 80      93
# 144     92
# 177     90
# 159     84
# Name: runs, dtype: int64

# %% [markdown]
# Short_index

# %%
sortindex = bollywood['movie'].sort_index()
sortindex
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1495                  Hum Tumhare Hain Sanam
# 1496                     Aankhen (2002 film)
# 1497                         Saathiya (film)
# 1498                          Company (film)
# 1499                    Awara Paagal Deewana
# Name: movie, Length: 1500, dtype: object

# %%
bollywood
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
leadactor = bollywood['lead'].sort_index(ascending=False)
leadactor
# Out:
# 1499        Akshay Kumar
# 1498          Ajay Devgn
# 1497        Vivek Oberoi
# 1496    Amitabh Bachchan
# 1495      Shah Rukh Khan
#               ...
# 4       Mona Ambegaonkar
# 3          Emraan Hashmi
# 2            Anupam Kher
# 1            Vicky Ahuja
# 0          Vicky Kaushal
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# size and count (size is count the messing value but count are not )

# %%
bollywood.count()
# Out:
# movie    1500
# lead     1500
# dtype: int64

# %% [markdown]
# sum --> product (product multply all the number one by one)

# %%
sub = pd.read_csv('subs.csv')
sub
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
sub.sum()
# Out:
# Subscribers gained    49510
# dtype: int64

# %% [markdown]
# mean > median > mode > std > var

# %%
sub.mean()
# Out:
# Subscribers gained    135.643836
# dtype: float64

# %%
vk.median()
# Out:
# match_no    108.0
# runs         24.0
# dtype: float64

# %%
bollywood.mode()
# Out:
#                      movie          lead
# 0                   Andaaz  Akshay Kumar
# 1           Gabbar Is Back           NaN
# 2  Tanu Weds Manu: Returns           NaN

# %%
sub.std() #stander devations
# Out:
# Subscribers gained    62.675023
# dtype: float64

# %%
sub.var()
# Out:
# Subscribers gained    3928.158513
# dtype: float64

# %%
sub.describe()
# Out:
#        Subscribers gained
# count          365.000000
# mean           135.643836
# std             62.675023
# min             33.000000
# 25%             88.000000
# 50%            123.000000
# 75%            177.000000
# max            396.000000

# %%
# fancy indexing
fancy =bollywood['movie'][[1,2,3]]
fancy
# Out:
# 1                           Battalion 609
# 2    The Accidental Prime Minister (film)
# 3                         Why Cheat India
# Name: movie, dtype: object

# %%
# labels = bollywood['movie'][['Battalion 609']]
# labels

# %% [markdown]
# Edit

# %%
bollywood["lead"][0] = 300
bollywood
# Out:
# <ipython-input-200-8718e0b1f375>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   bollywood["lead"][0] = 300
# <ipython-input-200-8718e0b1f375>:1: SettingWithCopyWarning:
# ...

# %%
print(dir(bollywood))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__arrow_c_stream__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__dataframe_consortium_standard__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__'
# ...

# %% [markdown]
# Type conversion

# %%
sub
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
dict(sub)
# Out:
# {'Subscribers gained': 0       48
#  1       57
#  2       40
#  3       43
#  4       44
#        ...
#  360    231
#  361    226
#  362    155
#  363    144
#  364    172
#  Name: Subscribers gained, Length: 365, dtype: int64}

# %%
# member ship operator
bollywood.head(2)
# Out:
#                       movie         lead    0  hello
# 0  Uri: The Surgical Strike          300  100    300
# 1             Battalion 609  Vicky Ahuja  100    300

# %%
"Battalion 609" in bollywood['movie'].values
# Out:
# True

# %%
#looping
for movie in bollywood['movie']:
  print(movie)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
100- vk["runs"]
# Out:
# 0       99
# 1       77
# 2       87
# 3       88
# 4       99
#       ...
# 210    100
# 211     80
# 212     27
# 213     75
# 214     93
# Name: runs, Length: 215, dtype: int64

# %% [markdown]
# if you want to true value print in the table then do this

# %%
vk[50>= vk['runs']]
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 209       210    30
# 210       211     0
# 211       212    20
# 213       214    25
# 214       215     7
#
# [167 rows x 2 columns]

# %% [markdown]
# if number of runs you can find

# %%
vk[vk['runs'] == 0].size
# Out:
# 18

# %%
vk[vk['runs'] >150].size
# Out:
# 0

# %%
vk
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
bollywood
# Out:
#                                      movie              lead    0  hello
# 0                 Uri: The Surgical Strike               300  100    300
# 1                            Battalion 609       Vicky Ahuja  100    300
# 2     The Accidental Prime Minister (film)       Anupam Kher  100    300
# 3                          Why Cheat India     Emraan Hashmi  100    300
# 4                          Evening Shadows  Mona Ambegaonkar  100    300
# ...                                    ...               ...  ...    ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan  100    300
# 1496                   Aankhen (2002 film)  Amitabh Bachchan  100    300
# 1497                       Saathiya (film)      Vivek Oberoi  100    300
# 1498                        Company (film)        Ajay Devgn  100    300
# 1499                  Awara Paagal Deewana      Akshay Kumar  100    300
#
# [1500 rows x 4 columns]

# %% [markdown]
# mearge bollywood data set and subs data set by id

# %%
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
bollywood
# Out:
#                                      movie              lead    0  hello
# 0                 Uri: The Surgical Strike               300  100    300
# 1                            Battalion 609       Vicky Ahuja  100    300
# 2     The Accidental Prime Minister (film)       Anupam Kher  100    300
# 3                          Why Cheat India     Emraan Hashmi  100    300
# 4                          Evening Shadows  Mona Ambegaonkar  100    300
# ...                                    ...               ...  ...    ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan  100    300
# 1496                   Aankhen (2002 film)  Amitabh Bachchan  100    300
# 1497                       Saathiya (film)      Vivek Oberoi  100    300
# 1498                        Company (film)        Ajay Devgn  100    300
# 1499                  Awara Paagal Deewana      Akshay Kumar  100    300
#
# [1500 rows x 4 columns]

# %% [markdown]
# it is only work if both dataframe have the same colum name

# %%
meargeeachother = pd.mearge(bollywood,subs,on='id ', right_on='id')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-254-cd9efa5cb651> in <cell line: 1>()
# ----> 1 meargeeachother = pd.mearge(bollywood,subs,on='id ', right_on='id')
#
# AttributeError: module 'pandas' has no attribute 'mearge'

# %% [markdown]
# if we dont have the common column in both dataframe the do this

# %%
meargedataframe = pd.concat([bollywood,subs],axis=1)
meargedataframe
# Out:
#                                      movie              lead    0  hello  \
# 0                 Uri: The Surgical Strike               300  100    300
# 1                            Battalion 609       Vicky Ahuja  100    300
# 2     The Accidental Prime Minister (film)       Anupam Kher  100    300
# 3                          Why Cheat India     Emraan Hashmi  100    300
# 4                          Evening Shadows  Mona Ambegaonkar  100    300
# ...                                    ...               ...  ...    ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan  100    300
# 1496                   Aankhen (2002 film)  Amitabh Bachchan  100    300
# 1497                       Saathiya (film)      Vivek Oberoi  100    300
# 1498                        Company (film)        Ajay Devgn  100    300
# 1499                  Awara Paagal Deewana      Akshay Kumar  100    300
#
#       Subscribers gained
# 0                   48.0
# 1                   57.0
# ...

# %%
meargedataframe.isnull().sum()
# Out:
# movie                    0
# lead                     0
# 0                        0
# hello                    0
# Subscribers gained    1135
# dtype: int64

# %%
meargedataframe.isnull().sum()
# Out:
# movie                    0
# lead                     0
# 0                        0
# hello                    0
# Subscribers gained    1135
# dtype: int64

# %%
from re import A
# df_cleaned = meargedataframe.drop(axis=1)
# df_cleaned.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-267-fda63ea2a98e> in <cell line: 2>()
#       1 from re import A
# ----> 2 df_cleaned = meargedataframe.drop(axis=1)
#       3 df_cleaned.isnull().sum()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4778                 axes["columns"] = columns
#    4779         else:
# -> 4780             raise ValueError(
#    4781                 "Need to specify at least one of 'labels', 'index' or 'columns'"
# ...

# %%
df_cleaned_cols = meargedataframe.dropna()
df_cleaned_cols
# Out:
#                                     movie              lead    0  hello  \
# 0                Uri: The Surgical Strike               300  100    300
# 1                           Battalion 609       Vicky Ahuja  100    300
# 2    The Accidental Prime Minister (film)       Anupam Kher  100    300
# 3                         Why Cheat India     Emraan Hashmi  100    300
# 4                         Evening Shadows  Mona Ambegaonkar  100    300
# ..                                    ...               ...  ...    ...
# 360                                ABCD 2       Prabhu Deva  100    300
# 361                   Dilwale (2015 film)    Shah Rukh Khan  100    300
# 362                     Bajrangi Bhaijaan       Salman Khan  100    300
# 363                       Bajirao Mastani     Ranveer Singh  100    300
# 364                   Welcome Back (film)       Anil Kapoor  100    300
#
#      Subscribers gained
# 0                  48.0
# 1                  57.0
# 2                  40.0
# ...

# %%
df_cleaned_cols.isnull().sum()
# Out:
# movie                 0
# lead                  0
# 0                     0
# hello                 0
# Subscribers gained    0
# dtype: int64

# %%
meargedataframe.isnull().sum()
# Out:
# movie                    0
# lead                     0
# 0                        0
# hello                    0
# Subscribers gained    1135
# dtype: int64

# %% [markdown]
# filling missing data

# %%
fillmissing = meargedataframe.fillna(1)
fillmissing.isnull().sum()
# Out:
# movie                 0
# lead                  0
# 0                     0
# hello                 0
# Subscribers gained    0
# dtype: int64

# %% [markdown]
# re-name the column

# %%
renamecolumn = meargedataframe.rename(columns={'movie':'aalu'})
renamecolumn
# Out:
#                                       aalu              lead    0  hello  \
# 0                 Uri: The Surgical Strike               300  100    300
# 1                            Battalion 609       Vicky Ahuja  100    300
# 2     The Accidental Prime Minister (film)       Anupam Kher  100    300
# 3                          Why Cheat India     Emraan Hashmi  100    300
# 4                          Evening Shadows  Mona Ambegaonkar  100    300
# ...                                    ...               ...  ...    ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan  100    300
# 1496                   Aankhen (2002 film)  Amitabh Bachchan  100    300
# 1497                       Saathiya (film)      Vivek Oberoi  100    300
# 1498                        Company (film)        Ajay Devgn  100    300
# 1499                  Awara Paagal Deewana      Akshay Kumar  100    300
#
#       Subscribers gained
# 0                   48.0
# 1                   57.0
# ...

# %% [markdown]
# Check the duplicate
#
# ---

# %%
duplicate = meargedataframe.duplicated()
duplicate.sum()
# Out:
# 2

# %%
meargedataframe
# Out:
#                                      movie              lead    0  hello  \
# 0                 Uri: The Surgical Strike               300  100    300
# 1                            Battalion 609       Vicky Ahuja  100    300
# 2     The Accidental Prime Minister (film)       Anupam Kher  100    300
# 3                          Why Cheat India     Emraan Hashmi  100    300
# 4                          Evening Shadows  Mona Ambegaonkar  100    300
# ...                                    ...               ...  ...    ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan  100    300
# 1496                   Aankhen (2002 film)  Amitabh Bachchan  100    300
# 1497                       Saathiya (film)      Vivek Oberoi  100    300
# 1498                        Company (film)        Ajay Devgn  100    300
# 1499                  Awara Paagal Deewana      Akshay Kumar  100    300
#
#       Subscribers gained
# 0                   48.0
# 1                   57.0
# ...

# %% [markdown]
# Remove the Duplicate

# %%
removeduplicate = meargedataframe.drop_duplicates()
removeduplicate
# Out:
#                                      movie              lead    0  hello  \
# 0                 Uri: The Surgical Strike               300  100    300
# 1                            Battalion 609       Vicky Ahuja  100    300
# 2     The Accidental Prime Minister (film)       Anupam Kher  100    300
# 3                          Why Cheat India     Emraan Hashmi  100    300
# 4                          Evening Shadows  Mona Ambegaonkar  100    300
# ...                                    ...               ...  ...    ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan  100    300
# 1496                   Aankhen (2002 film)  Amitabh Bachchan  100    300
# 1497                       Saathiya (film)      Vivek Oberoi  100    300
# 1498                        Company (film)        Ajay Devgn  100    300
# 1499                  Awara Paagal Deewana      Akshay Kumar  100    300
#
#       Subscribers gained
# 0                   48.0
# 1                   57.0
# ...

# %%
matches = pd.read_csv('matches - matches.csv')
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
matches.size
# Out:
# 11448

# %%
matches.shape
# Out:
# (636, 18)

# %%
matches.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
matches['id']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 631    632
# 632    633
# 633    634
# 634    635
# 635    636
# Name: id, Length: 636, dtype: int64

# %% [markdown]
# only column hear are print

# %%
columnhead = matches.columns
columnhead
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %% [markdown]
# selected column data only store in the variable

# %%
selectedcolumn = matches[['id','city','result','venue']]
selectedcolumn
# Out:
#       id       city  result                                             venue
# 0      1  Hyderabad  normal         Rajiv Gandhi International Stadium, Uppal
# 1      2       Pune  normal           Maharashtra Cricket Association Stadium
# 2      3     Rajkot  normal            Saurashtra Cricket Association Stadium
# 3      4     Indore  normal                            Holkar Cricket Stadium
# 4      5  Bangalore  normal                             M Chinnaswamy Stadium
# ..   ...        ...     ...                                               ...
# 631  632     Raipur  normal  Shaheed Veer Narayan Singh International Stadium
# 632  633  Bangalore  normal                             M Chinnaswamy Stadium
# 633  634      Delhi  normal                                  Feroz Shah Kotla
# 634  635      Delhi  normal                                  Feroz Shah Kotla
# 635  636  Bangalore  normal                             M Chinnaswamy Stadium
#
# [636 rows x 4 columns]

# %%
selectedcolumn.shape
# Out:
# (636, 4)

# %%
selectedcolumn.size
# Out:
# 2544

# %%
selectedcolumn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      636 non-null    int64
#  1   city    629 non-null    object
#  2   result  636 non-null    object
#  3   venue   636 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 20.0+ KB

# %%
selectedcolumn.iloc[2:14:4] # first number to start and meddle number are ending point and last one is jup the number
# Out:
#     id       city  result                                   venue
# 2    3     Rajkot  normal  Saurashtra Cricket Association Stadium
# 14  15      Delhi  normal                        Feroz Shah Kotla
# 4    5  Bangalore  normal                   M Chinnaswamy Stadium

# %%
selectedcolumn.iloc[[1,4,6,7,19]] # if you y \h to data extracct by the numbe the use this
# Out:
#     id       city  result                                    venue
# 1    2       Pune  normal  Maharashtra Cricket Association Stadium
# 4    5  Bangalore  normal                    M Chinnaswamy Stadium
# 6    7     Mumbai  normal                         Wankhede Stadium
# 7    8     Indore  normal                   Holkar Cricket Stadium
# 19  20     Rajkot  normal   Saurashtra Cricket Association Stadium

# %%
selectedcolumn.iloc[:,[4:5:10]]
# Out:
#   File "<ipython-input-67-ec042726cd79>", line 1
#     selectedcolumn.iloc[:,[4:5:10]]
#                             ^
# SyntaxError: invalid syntax
